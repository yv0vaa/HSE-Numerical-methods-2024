# %%
import pandas as pd
df = pd.read_csv('out.csv')
df.head()
# Out:
#    t          x          y          z
# 0  0 -5395550.0 -5461130.0 -5502780.0
# 1  1 -5396580.0 -5462180.0 -5503830.0
# 2  2 -5397620.0 -5463220.0 -5504880.0
# 3  3 -5398660.0 -5464270.0 -5505930.0
# 4  4 -5399700.0 -5465310.0 -5506980.0

# %%
import matplotlib.pyplot as plt
plt.plot(df['t'], df['x'])

# %%
plt.plot(df['t'], df['z'])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['x'], df['y'], df['z'], c='r')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
