# %%
import pandas as pd
df = pd.read_csv('out.csv')
df.head()
# Out:
#    t         x  y        z
# 0  0   7.29018  0  7500.00
# 1  1  14.58040  0  7499.99
# 2  2  21.87050  0  7499.97
# 3  3  29.16060  0  7499.94
# 4  4  36.45080  0  7499.91

# %%
import matplotlib.pyplot as plt
plt.plot(df['t'], df['x'])

# %%
plt.plot(df['t'], df['z'])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['x'], df['y'], df['z'], c='r')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
